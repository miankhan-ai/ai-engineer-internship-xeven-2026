# %% [markdown]
# # Task 1: Environment Setup & First Script

# %% [markdown]
# # Python Installation
# Installed Python 3.11 from official website and verified using python --version.

# %% [markdown]
# # VS Code Installation
# Installed VS Code and Python extension.

# %% [markdown]
# # Virtual Environment
# Created isolated environment using venv.

# %% [markdown]
# # UV Installation
# Installed UV package manager and verified installation.

# %% [markdown]
# # Git Setup
# Configured Git username and email.

# %% [markdown]
# # Screenshots
# 1. Python Version:
#
# ![image.png](attachment:906a01de-86df-4e78-8895-aa7325255c40.png)
#
# 2. VS Code with app.py open
#
# ![image.png](attachment:e2a33f9d-fad5-408a-9705-fb2618a39846.png)
#
# 3. Terminal running app.py
#
# ![image.png](attachment:7e7ae94a-b51e-48f2-a3c1-282aafccd1f7.png)

# %% [markdown]
# # Troubleshooting notes
# - Added Python to PATH during installation.
# - Restarted terminal after UV installation.
# - Verified Git configuration using git config --list.
